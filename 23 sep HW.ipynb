# %%
s="Rutika Zol"
print(len(s))
print(s[0:5])
print(s[5:])
print(s[:5])
print(s[5::+1])
print(s[::2])
print(s[::-1])
print(s[1::2])
print(s[:])
print(s[1:8:2])
print(s[-4:])
print(s[-8:-1])
print(s[-6:])
print(s[-10:-5])
print(s[-1:-6:-1])
print(s[-8::2])
print(s[-1:-8:-2])
print(s[-7:])
print(s[2:5:+1])
# Out:
# 10
# Rutik
# a Zol
# Rutik
# a Zol
# Rtk o
# loZ akituR
# uiaZl
# Rutika Zol
# uiaZ
#  Zol
# tika Zo
# ka Zol
# Rutik
# loZ a
# tk o
# lZai
# ika Zol
# tik
